# %%
import pandas as pd
import pickle
from statsmodels.tsa.statespace.sarimax import SARIMAX

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../../data/pre_data.csv", parse_dates=True)

# %%
for item in df["Tên_mặt_hàng"].unique():
    item_df = df[df["Tên_mặt_hàng"]==item]

    y = item_df["Giá"]
    X = item_df[["Thị_trường", "Loại_giá", "Nguồn"]]

    model = SARIMAX(
        y,
        exog=X,         
        order=(1,1,1),
        seasonal_order=(0,0,0,0),
    )

    results = model.fit()

    with open(f"../../models/sarimax/{item}.pkl", "wb") as file:
        pickle.dump(results, file)

# %%
forecast = results.get_forecast(steps=1, exog=[[0, 0, 0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Apps\miniconda\envs\project\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:1777, in MLEModel._validate_out_of_sample_exog(self, exog, out_of_sample)
#    1776 try:
# -> 1777     exog = exog.reshape(required_exog_shape)
#    1778 except ValueError:
#
# ValueError: cannot reshape array of size 2 into shape (1,3)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 forecast = results.get_forecast(steps=1, exog=[[0, 0]])
#
# File d:\Apps\miniconda\envs\project\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3418, in MLEResults.get_forecast(self, steps, signal_only, **kwargs)
#    3416 else:
#    3417     end = steps
# -> 3418 return self.get_prediction(start=self.nobs, end=end,
#    3419                            signal_only=signal_only, **kwargs)
#
# File d:\Apps\miniconda\envs\project\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3356, in MLEResults.get_prediction(self, start, end, dynamic, information_set, signal_only, index, exog, extend_model, extend_kwargs, **kwargs)
#    3353     extend_model = (self.model.exog is not None or
#    3354                     not self.filter_results.time_invariant)
#    3355 if out_of_sample and extend_model:
# -> 3356     kwargs = self.model._get_extension_time_varying_matrices(
#    3357         self.params, exog, out_of_sample, extend_kwargs,
#    3358         transformed=True, includes_fixed=True, **kwargs)
#    3360 # Make sure the model class has the current parameters
#    3361 self.model.update(self.params, transformed=True, includes_fixed=True)
#
# File d:\Apps\miniconda\envs\project\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1721, in SARIMAX._get_extension_time_varying_matrices(self, params, exog, out_of_sample, extend_kwargs, transformed, includes_fixed, **kwargs)
#    1711 """
#    1712 Get time-varying state space system matrices for extended model
#    1713
#    (...)   1717 special handling in the `simple_differencing=True` case.
#    1718 """
#    1720 # Get the appropriate exog for the extended sample
# -> 1721 exog = self._validate_out_of_sample_exog(exog, out_of_sample)
#    1723 # Get the tmp endog, exog
#    1724 if self.simple_differencing:
#
# File d:\Apps\miniconda\envs\project\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:1779, in MLEModel._validate_out_of_sample_exog(self, exog, out_of_sample)
#    1777         exog = exog.reshape(required_exog_shape)
#    1778     except ValueError:
# -> 1779         raise ValueError('Provided exogenous values are not of the'
#    1780                          ' appropriate shape. Required %s, got %s.'
#    1781                          % (str(required_exog_shape),
#    1782                             str(exog.shape)))
#    1783 elif k_exog > 0 and exog is not None:
#    1784     exog = None
#
# ValueError: Provided exogenous values are not of the appropriate shape. Required (1, 3), got (1, 2).

# %%
forecast.predicted_mean
# Out:
# 10   -83468.271488
# dtype: float64

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/data.csv")

# %%
df.head()
# Out:
#              Tên_mặt_hàng Thị_trường            Loại_giá Đơn_vị_tính  \
# 0  Cà phê Robusta nhân xô    Đắk Lắk  Thương lái thu mua      VNĐ/kg
# 1  Cà phê Robusta nhân xô   Lâm Đồng  Thương lái thu mua      VNĐ/kg
# 2  Cà phê Robusta nhân xô    Đắk Lắk  Thương lái thu mua      VNĐ/kg
# 3  Cà phê Robusta nhân xô   Lâm Đồng  Thương lái thu mua      VNĐ/kg
# 4  Cà phê Robusta nhân xô    Đắk Lắk  Thương lái thu mua      VNĐ/kg
#
#   Loại_tiền           Nguồn        Ngày      Giá Ngành_hàng
# 0       VNĐ  CTV địa phương  2020-01-01  32639.0     Cà phê
# 1       VNĐ  CTV địa phương  2020-01-01  32000.0     Cà phê
# 2       VNĐ  CTV địa phương  2020-01-02  32639.0     Cà phê
# 3       VNĐ  CTV địa phương  2020-01-02  32000.0     Cà phê
# 4       VNĐ  CTV địa phương  2020-01-03  32539.0     Cà phê

# %%
df.shape
# Out:
# (51485, 9)

# %%
items = df["Tên_mặt_hàng"].unique()

# %%
print(len(items))
# Out:
# 394

# %%
areas = df["Thị_trường"].unique()

# %%
print(len(areas))
# Out:
# 22

# %%
sources = df["Nguồn"].unique()

# %%
print(len(sources))
# Out:
# 14

# %%
sources
# Out:
# array(['CTV địa phương', 'CTV Agroinfo/ Tintaynguyen', 'huyện Thái Thụy',
#        'Thành phố Thái Bình', 'huyện Quỳnh Phụ', 'huyện Kiến Xương',
#        'huyện Đông Hưng', 'Bán lẻ', 'Cờ Đỏ', 'Cao Lãnh', 'Giồng Riềng',
#        'Long Xuyên', 'Tri Tôn', 'Tỉnh An Giang'], dtype=object)

# %%
units = df["Đơn_vị_tính"].unique()
print(len(units))
# Out:
# 10

# %%
print(units)
# Out:
# ['VNĐ/kg' 'VNĐ/Kg' 'VNĐ/Chục quả' 'VNĐ/Quả' 'VNĐ/quả' 'VNĐ/mớ' 'VNĐ/cây'
#  'Vnđ/Kg' 'VNĐ/củ' 'Đồng/kg']

# %%
print(df["Loại_giá"].unique())
# Out:
# ['Thương lái thu mua' 'Bán lẻ' 'Thu mua tại vườn' 'Công ty thu mua'
#  'Đại lý thu mua' 'Vựa thu mua' 'Bán buôn' 'Tại chợ' 'Khác' 'Xuất khẩu'
#  'Thu mua' 'Bán ra']
